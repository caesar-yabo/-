# %%
from ggplot import *

# %%
ggplot(mpg, aes('displ', 'hwy')) + \
geom_point()
# Out:
# <ggplot: (190415204367)>

# %%
mpg.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
ggplot(mpg, aes('displ', 'hwy', color = 'drv')) + \
geom_point()
# Out:
# <ggplot: (-9223371953930769597)>

# %%
ggplot(mpg, aes('displ', 'hwy', size = 'drv')) + \
geom_point()
# Out:
# <ggplot: (82924038355)>

# %%
ggplot(mpg, aes('displ', 'hwy', shape = 'drv')) + \
geom_point()
# Out:
# <ggplot: (82924726620)>

# %%
mpg.head(2)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
ggplot(mpg, aes('displ', 'hwy', color = 'drv')) + \
geom_line()
# Out:
# <ggplot: (-9223371953929459754)>

# %%
ggplot(mpg, aes('displ', 'hwy')) +\
geom_point(aes(color = 'blue'))
# Out:
# <ggplot: (82925538091)>

# %%
ggplot(mpg, aes('displ', 'hwy')) +\
geom_point(color = 'blue')
# Out:
# <ggplot: (-9223371953929211220)>

# %%
ggplot(mpg, aes('displ', 'hwy')) +\
geom_point(color = 'blue') +\
facet_wrap('class')
# Out:
# <ggplot: (82925817650)>

# %%
x1 = mpg.displ
y1 = mpg.hwy
geom_point(x1, y1) + stat_smooth(x1, y1)

# %%
import pandas
from pandas import Series
ggplot(mpg, aes(Series(mpg.displ),Series(mpg.hwy))) +\
geom_point(color = 'blue') +\
stat_smooth('class')
# Out:
# F:\Anaconda3-5-1\lib\site-packages\pandas\core\ops.py:816: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-63a55a3990b1> in <module>()
#       1 import pandas
#       2 from pandas import Series
# ----> 3 ggplot(mpg, aes(Series(mpg.displ),Series(mpg.hwy))) +geom_point(color = 'blue') +stat_smooth('class')
#
# F:\Anaconda3-5-1\lib\site-packages\ggplot\ggplot.py in __init__(self, aesthetics, data)
#      53         self._aes = aesthetics
#      54         self.data = data.copy()
# ---> 55         self._handle_index()
#      56         self.data = self._aes._evaluate_expressions(self.data)
#      57         self.data = self._aes.handle_identity_values(self.data)
#
# ...

# %%
ggplot(mpg, aes('drv', 'hwy')) +\
geom_point()
# Out:
# <ggplot: (-9223371953926634734)>

# %%
ggplot(mpg, aes('drv', 'hwy')) +\
geom_jitter(size = 120)
# Out:
# <ggplot: (82928211155)>

# %%
#help(geom_jitter)

# %%
#help(stat_smooth)

# %%
mpg1 = mpg.loc[mpg.drv == 'f']
ggplot(mpg1, aes('drv','hwy')) +\
geom_boxplot()
# Out:
# <ggplot: (-9223371953925043361)>

# %%
#help(geom_density)

# %%
ggplot(mpg, aes('hwy', color = 'drv')) +\
geom_density()
# Out:
# <ggplot: (82929997369)>

# %%
ggplot(mpg, aes('manufacturer')) +\
geom_bar()
# Out:
# <ggplot: (-9223371953925558128)>

# %%
dir(ggplot)
# Out:
# ['CONTINUOUS',
#  'DISCRETE',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_construct_plot_data',
#  '_get_mapping',
#  '_handle_index',
#  '_iterate_subplots',
#  '_prep_layer_for_plotting',
#  'add_labels',
#  'add_legend',
#  'apply_axis_labels',
#  'apply_axis_scales',
#  'apply_coords',
#  'apply_limits',
#  'apply_scales',
#  'apply_theme',
#  'get_facet_groups',
#  'get_subplot',
#  'make',
#  'make_facets',
#  'save',
#  'save_as_base64',
#  'show']

# %%
china_map = readShapePoly("D:\\My_R_Data\\CHN_adm_shp\\CHN_adm2.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-81-42a20acbef67> in <module>()
# ----> 1 china_map = readShapePoly("D:\\My_R_Data\\CHN_adm_shp\\CHN_adm2.shp")
#
# NameError: name 'readShapePoly' is not defined

# %%
from geopandas import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-82-998e871db758> in <module>()
# ----> 1 from geopandas import *
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5.0, 5.0, 0.02)
y1 = np.sin(x)

plt.figure(1, figsize = [20, 20])
plt.subplot(211)
plt.axis([-5, 5, 0, 1])
plt.plot(x, y1, 'r-')

plt.subplot(212)
plt.axis([-2, 2, -1, 1])

plt.plot(x, y1)

plt.show()

# %% [markdown]
# # 关于线的作图

# %%
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号

t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
#, 'r--', t, t**2, 'bs', t, t**3, 'g^'
plt.figure(figsize=[10, 10])
plt.style.use('ggplot')
plt.plot(t, t, 'r--', label = '1')
plt.plot(t, t**2, 'bs', label = '2')
plt.plot(t, t**3, 'g.', label = '3')
plt.text(2.5, 2.5**2, '*', size = 20)
plt.annotate('mean', xy=(2.5, 20), xytext=(3, 30),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )

plt.axis([0, 5, 0, 100])

plt.title('这是牛逼的图')
plt.xlabel('t')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
https://www.cnblogs.com/zhizhan/p/5615947.html

# %%
import numpy as np
import matplotlib.pyplot as plt
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号

# %%
x = np.linspace(-5, 5, 100)
y = np.sin(x)
z = np.cos(x)
plt.figure(figsize=[10, 10])
plt.style.use('ggplot')
plt.plot(x, y, 'r--', label = 'Y')
plt.plot(x, z, 'b-', label = 'Z')
plt.annotate('mean', size = 20, xy=(0, 0), xytext=(2, 1.5),
            arrowprops=dict(facecolor='g', shrink=1),
            )
#plt.axis([-4, 4, -1, 1])
plt.xlim([-4, 4])
plt.ylim([-2, 2])
plt.title('sin', size = 20)
plt.xlabel('X', size = 20)
plt.xlabel('Y', size = 20)
plt.legend()
plt.show()

# %% [markdown]
# # 散点图

# %%
x = np.random.randn(1000)
y = np.random.randn(1000)

# %%
x = np.ones(100)
y = np.ones(100)

plt.figure(figsize = [10, 10])
color = ['red', 'green', 'blue', 'orange']
e1 = np.random.normal(0, 0.1, 100)
e2 = np.random.normal(0, 0.1, 100)
plt.scatter(x + e1, y + e2, c = color, marker='D', alpha = 0.9, edgecolors = 'w', s = 20)
plt.title('Scatter')
plt.xlabel('X_random')
plt.ylabel('Y_random')
# plt.annotate('(0, 0)', size = 20, xy=(0, 0), xytext=(2, 1.5),
#             arrowprops=dict(facecolor='g', shrink=1),
#             )
plt.xlim([-3, 3])
plt.ylim([-3, 3])
plt.show()

# %%
import pandas as pd

# %%
f = open(r'D:\baijilin.csv', encoding='gbk')
mydata = pd.read_csv(f)

# %%
mydata = mydata[['样线起点经度', '样线起点纬度']]

# %%
plt.figure(figsize = [20, 20])
color = ['red', 'green', 'blue', 'orange']
n = len(mydata)
e1 = np.random.normal(0, 0.5, n)
e2 = np.random.normal(0, 0.5, n)
plt.scatter(mydata.iloc[:,0] + e1, mydata.iloc[:,1] + e2, c = color, marker='D', alpha = 0.9, edgecolors = 'w')
plt.title('Scatter')
plt.xlabel('jing')
plt.ylabel('wei')
# plt.annotate('(0, 0)', size = 20, xy=(0, 0), xytext=(2, 1.5),
#             arrowprops=dict(facecolor='g', shrink=1),
#             )
# plt.xlim([-3, 3])
# plt.ylim([-3, 3])
plt.show()

# %%
from mpl_toolkits.basemap import Basemap

# %%
# m=Basemap(projection='mill',lon_0=-105.,lat_0=90.,lat_ts=60.,\
#           llcrnrlat=25.,urcrnrlat=50.,\
#           llcrnrlon=-118.,urcrnrlon=-60.,\
#           rsphere=6371200.,resolution='l',area_thresh=10000)

plt.figure(figsize=(10,10))
#m = Basemap()
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
#m = Basemap(llcrnrlon=73, llcrnrlat=18, urcrnrlon=135, urcrnrlat=53)
m.drawcoastlines(linewidth=1.5)
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm0', 'states', color = 'black',drawbounds=True,  linewidth=3.5)
#m.drawcountries(linewidth=3.5)
x, y = m(np.array(mydata.iloc[:,0]) , np.array(mydata.iloc[:,1]))
m.scatter(x, y, c = 'r', marker='.', alpha = 0.9, edgecolors = 'w')
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm3', 'states', color = 'black',drawbounds=True,  linewidth=0.1)
plt.show()

# %%
plt.figure(figsize=(10,10))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm2', 'states')#, color = 'black',drawbounds=True,  linewidth=0.1)
x, y = m(np.array(mydata.iloc[:,0]) , np.array(mydata.iloc[:,1]))
m.scatter(x, y, c = 'r', marker='.', alpha = 0.9, edgecolors = 'w')
plt.title('density map')
plt.show()

# %%
f = open(r'D:\text.csv', encoding='gbk')
mydata = pd.read_csv(f)
size = np.array(mydata.iloc[:,2]/np.max(mydata.iloc[:,2])) * 1000

plt.figure(figsize = [10, 10])
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm1', 'states', color = 'k',drawbounds=True,  linewidth=1)
x, y = m(np.array(mydata.iloc[:,0] + 0.1*e1) , np.array(mydata.iloc[:,1] + 0.1*e2))
m.scatter(x, y, c = 'g', s=size, marker='.', alpha = 0.9, edgecolors = 'w')
for i in range(n):
    if size[i] == 1000:
        plt.annotate('mean', xy=(x[i], y[i]))#, xytext=(3, 30),arrowprops=dict(facecolor='black', shrink=0.05))
plt.title('density map')
plt.show()

# %%
map_data
# Out:
# (2408,
#  5,
#  [73.55770111083996, 18.159305572509766, 0.0, 0.0],
#  [134.77392578125, 53.5608596801759, 0.0, 0.0],
#  <matplotlib.collections.LineCollection at 0x2c55cc5e8d0>)

# %%
from mpl_toolkits.basemap import Basemap
# set up map projection with
# use low resolution coastlines.
plt.figure(figsize = [10, 10])
#map = Basemap(projection='ortho',lat_0=35,lon_0=120,resolution='l')
map = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
# draw coastlines, country boundaries, fill continents.
map.drawcoastlines(linewidth=0.25)
map.drawcountries(linewidth=1)
# draw the edge of the map projection region (the projection limb)
#map.drawmapboundary(fill_color='#689CD2')
# draw lat/lon grid lines every 30 degrees.
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))
# Fill continent wit a different color
#map.fillcontinents(color='#BF9E30',lake_color='#689CD2',zorder=0)
# compute native map projection coordinates of lat/lon grid.
x, y = map(np.array(mydata.iloc[:,0] + 0.1*e1) , np.array(mydata.iloc[:,1] + 0.1*e2))
cs = map.scatter(x,y,s=0.5,marker='o',color='#FF5600')



# max_pop = max(pops)
# # Plot each city in a loop.
# # Set some parameters
# size_factor = 80.0
# y_offset    = 15.0
# rotation    = 30
# for i,j,k,name in zip(x,y,pops,names):
#     size = size_factor*k/max_pop
#     cs = map.scatter(i,j,s=size,marker='o',color='#FF5600')
#     plt.text(i,j+y_offset,name,rotation=rotation,fontsize=10)

plt.title('density map')
plt.show()

# %%
'''Shanghai 23019148  31.23N  121.47E  China
Mumbai   12478447  18.96N  72.82E   India
Karachi  13050000  24.86N  67.01E   Pakistan
Delhi    16314838  28.67N  77.21E   India
Manila   11855975  14.62N  120.97E  Philippines
Seoul    23616000  37.56N  126.99E  Korea(South)
Jakarta  28019545   6.18S  106.83E  Indonesia
Tokyo    35682460  35.67N  139.77E  Japan
Peking   19612368  39.91N  116.39E  China'''

names = ['Shanghai', 'Mumbai', 'Karachi']
pops  = [23019148, 12478447, 13050000]
lats  = [31.23, 18.96, 24.86]
lons  = [121.47, 72.82, 67.01]
countries = ['China', 'India', 'Pakistan']

# %%
plt.figure(figsize = [10, 10])
# set up map projection with
# use low resolution coastlines.
#map = Basemap(projection='lcc',lat_0=35,lon_0=120,resolution='l')
map = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
# draw coastlines, country boundaries, fill continents.
map.drawcoastlines(linewidth=0.25)
map.drawcountries(linewidth=0.25)
# draw the edge of the map projection region (the projection limb)
#map.drawmapboundary(fill_color='#689CD2')
# draw lat/lon grid lines every 30 degrees.
map.drawmeridians(np.arange(0,360,30))
map.drawparallels(np.arange(-90,90,30))
# Fill continent wit a different color
#map.fillcontinents(color='#BF9E30',lake_color='#689CD2',zorder=0)
# compute native map projection coordinates of lat/lon grid.
x, y = map(lons, lats)
max_pop = max(pops)
# Plot each city in a loop.
# Set some parameters
size_factor = 80.0
y_offset    = 15.0
rotation    = 30
for i,j,k,name in zip(x,y,pops,names):
    size = size_factor*k/max_pop
    cs = map.scatter(i,j,s=size,marker='o',color='#FF5600')
    plt.text(i,j+y_offset,name,rotation=rotation,fontsize=10)

plt.title('Major Cities in Asia & Population')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
mpl.rcParams['axes.unicode_minus']=False #用来正常显示负号

f = open(r'D:\text.csv', encoding='gbk')
my_data = pd.read_csv(f)

n = len(my_data)
e1 = np.random.normal(0, 0.5, n)
e2 = np.random.normal(0, 0.5, n)


size = np.array(my_data.iloc[:,2]/np.max(my_data.iloc[:,2])) * 1000

plt.figure(figsize = [20, 20])
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm1', 'states', color = 'k',drawbounds=True,  linewidth=1)
x, y = m(np.array(my_data.iloc[:,0] + e1) , np.array(my_data.iloc[:,1] + e2))
m.scatter(x, y, c = 'g', s=size, marker='.', alpha = 0.9, edgecolors = 'w')
for i in range(n):
    if size[i] == 1000:
        plt.annotate(my_data.iloc[i,3], xy=(x[i], y[i]), size = 20, color = 'r')#, xytext=(x[i] + 1, y[i] + 1),arrowprops=dict(facecolor='black', shrink=1))
plt.title('散点图，也可以表示密度',size = 20)
plt.xlabel('经度', size = 20)
plt.ylabel('维度', size = 20)
plt.show()

###############

# %%
max_size = np.max(size)
#max_size = [x for x in size if x == max_of_size]

for i in range(n):
    for j in range(i, n):
        if my_data.iloc[j, 3] == max_size and my_data.iloc[i, 3] == max_size:
            if (np.abs(my_data.iloc[j, 0] - my_data.iloc[i, 0]) < 20) and (np.abs(my_data.iloc[j, 1] - my_data.iloc[i, 1]) < 20):
                my_data.iloc[j, 3] =  ''

# %%
plt.figure(figsize = [20, 20])
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.readshapefile(r'D:\My_R_Data\CHN_adm_shp\CHN_adm1', 'states', color = 'k',drawbounds=True,  linewidth=1)
x, y = m(np.array(my_data.iloc[:,0] + e1) , np.array(my_data.iloc[:,1] + e2))
m.scatter(x, y, c = 'g', s=size, marker='.', alpha = 0.9, edgecolors = 'w')
for i in range(n):
    if size[i] == 1000:
        plt.annotate(my_data.iloc[i,3], xy=(x[i], y[i]), size = 20, color = 'r')#, xytext=(x[i] + 1, y[i] + 1),arrowprops=dict(facecolor='black', shrink=1))
plt.title('散点图，也可以表示密度',size = 20)
plt.xlabel('经度', size = 20)
plt.ylabel('维度', size = 20)
plt.show()

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
plt.figure(figsize=(6, 3))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
ax.coastlines(resolution='110m')
ax.gridlines()

# %%
http://www.naturalearthdata.com/downloads/
https://blog.csdn.net/u010159842/article/details/70738854
http://scitools.org.uk/cartopy/docs/latest/gallery/

# %%
scale='110m'
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

# %%
fig=plt.figure(figsize=(8, 10))
ax=plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
ax.set_global()
land = cfeature.NaturalEarthFeature('physical', 'land', scale,edgecolor='face',
                                                              facecolor=cfeature.COLORS['land'])
ax.add_feature(land, facecolor='0.75')
ax.coastlines(scale)
ax.set_xticks([0, 60, 120, 180, 240, 300, 360], crs=ccrs.PlateCarree())
ax.set_yticks([-90, -60, -30, 0, 30, 60, 90], crs=ccrs.PlateCarree())
#zero_direction_label用来设置经度的0度加不加E和W
lon_formatter = LongitudeFormatter(zero_direction_label=False)
lat_formatter = LatitudeFormatter()
ax.xaxis.set_major_formatter(lon_formatter)
ax.yaxis.set_major_formatter(lat_formatter)
#添加网格线
gl = ax.gridlines()
# Out:
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
import matplotlib.pyplot as plt

import cartopy.crs as ccrs


def main():
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())

    # make the map global rather than have it zoom in to
    # the extents of any plotted data
    ax.set_global()

    ax.stock_img()
    ax.coastlines()

    ax.tissot(facecolor='orange', alpha=0.4)

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# F:\Anaconda3-5-1\lib\site-packages\cartopy\mpl\geoaxes.py:623: UserWarning: Approximating coordinate system <cartopy._crs.Geodetic object at 0x000001E6E77FC200> with the PlateCarree projection.
#   'PlateCarree projection.'.format(crs))

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt


def main():
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1, projection=ccrs.PlateCarree())
    ax.set_extent([-20, 60, -40, 45], crs=ccrs.PlateCarree())

    ax.add_feature(cfeature.LAND)
    ax.add_feature(cfeature.OCEAN)
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.BORDERS, linestyle=':')
    ax.add_feature(cfeature.LAKES, alpha=0.5)
    ax.add_feature(cfeature.RIVERS)

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_ocean.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_boundary_lines_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_lakes.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/physical/ne_110m_rivers_lake_centerlines.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import shapely.geometry as sgeom

import cartopy.crs as ccrs
import cartopy.io.shapereader as shpreader


def sample_data():
    """
    Return a list of latitudes and a list of longitudes (lons, lats)
    for Hurricane Katrina (2005).

    The data was originally sourced from the HURDAT2 dataset from AOML/NOAA:
    http://www.aoml.noaa.gov/hrd/hurdat/newhurdat-all.html on 14th Dec 2012.

    """
    lons = [-75.1, -75.7, -76.2, -76.5, -76.9, -77.7, -78.4, -79.0,
            -79.6, -80.1, -80.3, -81.3, -82.0, -82.6, -83.3, -84.0,
            -84.7, -85.3, -85.9, -86.7, -87.7, -88.6, -89.2, -89.6,
            -89.6, -89.6, -89.6, -89.6, -89.1, -88.6, -88.0, -87.0,
            -85.3, -82.9]

    lats = [23.1, 23.4, 23.8, 24.5, 25.4, 26.0, 26.1, 26.2, 26.2, 26.0,
            25.9, 25.4, 25.1, 24.9, 24.6, 24.4, 24.4, 24.5, 24.8, 25.2,
            25.7, 26.3, 27.2, 28.2, 29.3, 29.5, 30.2, 31.1, 32.6, 34.1,
            35.6, 37.0, 38.6, 40.1]

    return lons, lats


def main():
    fig = plt.figure()
    ax = fig.add_axes([0, 0, 1, 1], projection=ccrs.LambertConformal())

    ax.set_extent([-125, -66.5, 20, 50], ccrs.Geodetic())

    shapename = 'admin_1_states_provinces_lakes_shp'
    states_shp = shpreader.natural_earth(resolution='110m',
                                         category='cultural', name=shapename)

    lons, lats = sample_data()

    # to get the effect of having just the states without a map "background"
    # turn off the outline and background patches
    ax.background_patch.set_visible(False)
    ax.outline_patch.set_visible(False)

    ax.set_title('US States which intersect the track of '
                 'Hurricane Katrina (2005)')

    # turn the lons and lats into a shapely LineString
    track = sgeom.LineString(zip(lons, lats))

    # buffer the linestring by two degrees (note: this is a non-physical
    # distance)
    track_buffer = track.buffer(2)

    for state in shpreader.Reader(states_shp).geometries():
        # pick a default color for the land with a black outline,
        # this will change if the storm intersects with our track
        facecolor = [0.9375, 0.9375, 0.859375]
        edgecolor = 'black'

        if state.intersects(track):
            facecolor = 'red'
        elif state.intersects(track_buffer):
            facecolor = '#FF7E00'

        ax.add_geometries([state], ccrs.PlateCarree(),
                          facecolor=facecolor, edgecolor=edgecolor)

    ax.add_geometries([track_buffer], ccrs.PlateCarree(),
                      facecolor='#C8A2C8', alpha=0.5)
    ax.add_geometries([track], ccrs.PlateCarree(),
                      facecolor='none', edgecolor='k')

    # make two proxy artists to add to a legend
    direct_hit = mpatches.Rectangle((0, 0), 1, 1, facecolor="red")
    within_2_deg = mpatches.Rectangle((0, 0), 1, 1, facecolor="#FF7E00")
    labels = ['State directly intersects\nwith track',
              'State is within \n2 degrees of track']
    ax.legend([direct_hit, within_2_deg], labels,
              loc='lower left', bbox_to_anchor=(0.025, -0.1), fancybox=True)

    plt.show()


if __name__ == '__main__':
    main()
# Out:
# F:\Anaconda3-5-1\lib\site-packages\cartopy\io\__init__.py:260: DownloadWarning: Downloading: http://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_1_states_provinces_lakes_shp.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

plt.figure(figsize=(6, 3))
ax = plt.axes(projection=ccrs.PlateCarree(central_longitude=180))
ax.coastlines(resolution='110m')
ax.gridlines()

# %%
# Out:
#                                              .DS_Store
# 0                                            CHANGELOG
# 1               ne_10m_antarctic_ice_shelves_lines.cpg
# 2               ne_10m_antarctic_ice_shelves_lines.dbf
# 3               ne_10m_antarctic_ice_shelves_lines.prj
# 4       ne_10m_antarctic_ice_shelves_lines.README.html
# 5               ne_10m_antarctic_ice_shelves_lines.shp
# 6               ne_10m_antarctic_ice_shelves_lines.shx
# 7       ne_10m_antarctic_ice_shelves_lines.VERSION.txt
# 8               ne_10m_antarctic_ice_shelves_polys.cpg
# 9               ne_10m_antarctic_ice_shelves_polys.dbf
# 10              ne_10m_antarctic_ice_shelves_polys.prj
# 11      ne_10m_antarctic_ice_shelves_polys.README.html
# 12              ne_10m_antarctic_ice_shelves_polys.shp
# 13              ne_10m_antarctic_ice_shelves_polys.shx
# 14      ne_10m_antarctic_ice_shelves_polys.VERSION.txt
# 15                       ne_10m_bathymetry_A_10000.cpg
# ...
